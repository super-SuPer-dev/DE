# %%
print('HI')
# Out:
# HI

# %%
import pandas as pd

# %%
path = 'C:\\Users\\MSI_1650\\Desktop\\DE\\data\\silver\\youtube_clean.csv'
data = pd.read_csv(path)

# %%
data[data.university_search_term == 'สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง']
# Out:
#          video_id                                              title  \
# 4661  vKJJ0TDgZV0  ก่อนเข้า IT (Data Sci) ลาดกระบังทำอะไรบ้าง? | ...
# 4662  kq6kndge7Ds  พระจอมเกล้าฯลาดกระบัง! ร้านไหนเด็ด หอพักไหนดี ...
# 4663  AOuNjWP3QO8  วิศวะลาดกระบังมีภาคไหนบ้าง! เลือกสาขายังไง? ฉบ...
# 4664  SrFPuLx5LVQ    รีวิว ตึกใหม่ KMIDS ก่อนเปิดเทอม ทุกซอกทุกมุม!!
# 4665  XKpuIm42uQc  📍แนะนำตึกเรียนคณะวิศวกรรมศาสตร์ สจล. | Uni Tou...
# ...           ...                                                ...
# 5314  ZD9KqktmWcs  ค่ายเคมีสัมพันธ์ ตอนที่2  สถาบันเทคโนโลยีพระจอ...
# 5315  tnN6V16AMB4  ⚙️ รีวิวสาขาวิชาวิศวกรรมมัลติมีเดียและเอ็นเตอร...
# 5316  7gNhVHUCew0  เจ้เล้ง | พาชมหอพัก AJ Park ในปี 2024 ที่ทั้งส...
# 5317  yC7WP4Yj_WU  U - Review รีวิวสาขาวิชาวิศวกรรมคอมพิวเตอร์ คณ...
# 5318  rVdzbusjQr8  รีวิววิศวะอิเล็กทรอนิกส์ บางมด สั้นๆ #mewimi #...
#
#                    published_at       channel_title  view_count  like_count  \
# ...

# %%
display(data.university_search_term.value_counts())
# Out:
# university_search_term
# มหาวิทยาลัยเชียงใหม่                              745
# มหาวิทยาลัยสงขลานครินทร์                          713
# มหาวิทยาลัยขอนแก่น                                705
# สถาบันเทคโนโลยีพระจอมเกล้าเจ้าคุณทหารลาดกระบัง    658
# มหาวิทยาลัยธรรมศาสตร์                             654
# มหาวิทยาลัยมหิดล                                  654
# มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าธนบุรี             647
# จุฬาลงกรณ์มหาวิทยาลัย                             605
# มหาวิทยาลัยเกษตรศาสตร์                            585
# มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าพระนครเหนือ        242
# Name: count, dtype: int64
